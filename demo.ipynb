# %% [markdown]
# # Package installation

# %% [markdown]
# First, you need to uninstall the *torchaudio* and *torchdata* packages if you already have PyTorch >= 2.0. It is to make the enviornment compatible with the *synthcity* package.
#
# The *synthcity* team is already working on upgrading their requirements to PyTorch 2.0. See [here](https://github.com/vanderschaarlab/synthcity/issues/234).

# %%
# !yes | pip -q uninstall torchaudio torchdata

# %% [markdown]
# Remember to restart your kernel / runtime before proceeding to the next steps.
#
# Second, you need to install the Google gPS *auto_synthetic_data_platform* package.

# %%
# !pip install auto_synthetic_data_platform.tar.gz

# %% [markdown]
# Remember to restart your kernel / runtime before proceeding to the next steps.

# %% [markdown]
# # Imports

# %%
import pathlib
from auto_synthetic_data_platform import preprocessing
from auto_synthetic_data_platform import synthetic_data_model_tuning
import pandas as pd
from synthcity import plugins
from synthcity.plugins.core import dataloader

# %% [markdown]
# # Global variables

# %% [markdown]
# The below variables might need to be changed for your use case.

# %%
_REAL_DATAFRAME_PATH = "/content/real_dataset.csv"

# %% [markdown]
# # Dataset

# %% [markdown]
# For the demonstration purposes we are going to use a modified version of the Acquire Valued Shoppers Challenge that can be downloaded from [Kaggle](https://www.kaggle.com/competitions/acquire-valued-shoppers-challenge/data).

# %%
real_dataframe = pd.read_csv(_REAL_DATAFRAME_PATH)
real_dataframe.head()
# Out:
#    productsize  purchasequantity  purchaseamount  dept  category    company  \
# 0        128.0                 2            5.98    63      6315  101111010
# 1         16.0                 1            0.88     9       907  101111010
# 2        128.0                 1            2.39    63      6315  101111010
# 3         16.0                 1            0.99     9       907  101111010
# 4         12.0                 1            0.88     9       907  101111010
#
#    brand productmeasure
# 0   9907             OZ
# 1   9907             OZ
# 2   9907             OZ
# 3   9907             OZ
# 4   9907             OZ

# %% [markdown]
# # Loading data

# %% [markdown]
# ## Preprocessor

# %% [markdown]
# The *auto_synthetic_data_platform* has the *Preprocessor* class that can help preprocess the real dataset according to the industry best practices. It will also log all the information about the dataset that can impact a synthetic data model training. The logs can be shared externally in the you cannot allow external people to have access to your data and remote / blind synthetic data model training debugging is required.

# %%
_EXPERIMENT_DIRECTORY = ("/content/")
_COLUMN_METADATA = {
    "numerical": [
        "productsize",
        "purchasequantity",
        "purchaseamount",
    ],
    "categorical": [
        "dept",
        "category",
        "company",
        "brand",
        "productmeasure",
    ],
}
_PREPROCESS_METADATA = {
    "remove_numerical_outliers": False,
    "remove_duplicates": True,
    "preprocess_missing_values": True,
    "missing_values_method": "drop",
}

# %%
preprocessor = preprocessing.Preprocessor(
    dataframe_path=pathlib.Path(_REAL_DATAFRAME_PATH),
    experiment_directory=pathlib.Path(_EXPERIMENT_DIRECTORY),
    column_metadata=_COLUMN_METADATA,
    preprocess_metadata=_PREPROCESS_METADATA,
)

# %%
preprocessed_real_dataset = preprocessor.output_dataframe
# Out:
# INFO:preprocessing:No columns with missing values detected.
# WARNING:preprocessing:The categorical column 'dept' dimensionality is 4. The recommended column cardinality range is 50-100. Real and synthetic distribution metrics might get adversely affected.
# WARNING:preprocessing:A mild class imbalance detected in the 'dept' column for variables: 9, 97, 63.
# WARNING:preprocessing:A moderate class imbalance detected in the 'dept' column for variables: 99.
# WARNING:preprocessing:The categorical column 'category' dimensionality is 5. The recommended column cardinality range is 50-100. Real and synthetic distribution metrics might get adversely affected.
# WARNING:preprocessing:A mild class imbalance detected in the 'category' column for variables: 907, 9753, 6315.
# WARNING:preprocessing:A moderate class imbalance detected in the 'category' column for variables: 9909.
# WARNING:preprocessing:The categorical column 'company' dimensionality is 2. The recommended column cardinality range is 50-100. Real and synthetic distribution metrics might get adversely affected.
# WARNING:preprocessing:A mild class imbalance detected in the 'company' column for variables: 10000.
# WARNING:preprocessing:The categorical column 'brand' dimensionality is 2. The recommended column cardinality range is 50-100. Real and synthetic distribution metrics might get adversely affected.
# WARNING:preprocessing:A mild class imbalance detected in the 'brand' column for variables: 0.
# WARNING:preprocessing:The categorical column 'productmeasure' dimensionality is 2. The recommended column cardinality range is 50-100. Real and synthetic distribution metrics might get adversely affected.
# WARNING:preprocessing:A mild class imbalance detected in the 'productmeasure' column for variables: CT.

# %% [markdown]
# ## Synthcity data loading

# %% [markdown]
# The next step is to use a data loading module from *synthcity*.

# %%
data_loader = dataloader.GenericDataLoader(
    data=preprocessor.output_dataframe,
    target_column="purchaseamount",
)

# %% [markdown]
# # Synthetic data model training

# %% [markdown]
# ## Synthcity model selection

# %% [markdown]
# At this stage you need to load a synthetic data model instance from *synthcity*. The list of available models can be found [here](https://github.com/vanderschaarlab/synthcity#-methods).

# %%
_TVAE_MODEL = "tvae"
tvae_synthetic_data_model = plugins.Plugins().get(_TVAE_MODEL)
# Out:
# [2023-09-21T11:55:07.375435+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py

# %% [markdown]
# ## Objective/s selection

# %% [markdown]
# Now you need to define a mapping of evaluation metrics compatible with *synthcity*. Each model in the hyperparameter tuning process will be evaluated against these criteria to identify the best synthetic data model. The list of available metrics can be found [here](https://github.com/vanderschaarlab/synthcity#zap-evaluation-metrics).

# %%
_EVALUATION_METRICS = {
    "sanity": ["close_values_probability"],
    "stats": ["inv_kl_divergence"],
    "performance": ["xgb"],
    "privacy": ["k-anonymization"],
}

# %% [markdown]
# ## Tuner setup

# %% [markdown]
# Here, you will need to setup a synthetic data model tuner from the *auto_synthetic_data_platform* package.

# %%
_NUMBER_OF_TRIALS = 2
_OPTIMIZATION_DIRECTION = "maximize"
_TASK_TYPE = "regression"

# %%
tvae_synthetic_data_model_optimizer = synthetic_data_model_tuning.SyntheticDataModelTuner(
    data_loader=data_loader,
    synthetic_data_model=tvae_synthetic_data_model,
    experiment_directory=pathlib.Path(_EXPERIMENT_DIRECTORY),
    number_of_trials=_NUMBER_OF_TRIALS,
    optimization_direction=_OPTIMIZATION_DIRECTION,
    evaluation_metrics=_EVALUATION_METRICS,
    task_type=_TASK_TYPE,
)

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# The tuner runs a hyperparameter search in the background and then outputs the best synthetic data model. The processing time depends on the number of trials.
#
# **WARNING:** The process is resource intensive. Sometimes a kernel/ runtime needs to be restarted.

# %%
best_tvae_network_synthetic_data_model = (
    tvae_synthetic_data_model_optimizer.best_synthetic_data_model
    )
# Out:
# INFO:hyperparameter_optimization:Specified 'evaluation_metrics': {'sanity': ['close_values_probability'], 'stats': ['inv_kl_divergence'], 'performance': ['xgb'], 'privacy': ['k-anonymization']}. Optimization direction: 'maximize'.
# INFO:hyperparameter_optimization:Trial: trial_0. Model: tvae. Selected hyperparameters: {'n_iter': 400, 'lr': 0.0001, 'decoder_n_layers_hidden': 1, 'weight_decay': 0.001, 'batch_size': 512, 'n_units_embedding': 250, 'decoder_n_units_hidden': 250, 'decoder_nonlin': 'elu', 'decoder_dropout': 0.11346204368066007, 'encoder_n_layers_hidden': 5, 'encoder_n_units_hidden': 150, 'encoder_nonlin': 'tanh', 'encoder_dropout': 0.05081501879035502}
# [2023-09-21T11:55:08.557163+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 400/400 [01:28<00:00,  4.53it/s]
# INFO:hyperparameter_optimization:Trial: trial_1. Model: tvae. Selected hyperparameters: {'n_iter': 100, 'lr': 0.001, 'decoder_n_layers_hidden': 3, 'weight_decay': 0.0001, 'batch_size': 256, 'n_units_embedding': 350, 'decoder_n_units_hidden': 100, 'decoder_nonlin': 'tanh', 'decoder_dropout': 0.03137473872195671, 'encoder_n_layers_hidden': 5, 'encoder_n_units_hidden': 450, 'encoder_nonlin': 'leaky_relu', 'encoder_dropout': 0.06130705537690631}
# [2023-09-21T11:56:40.292617+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]
# INFO:hyperparameter_optimization:Model: tvae. Best hyperparameters: {'n_iter': 100, 'lr': 0.001, 'decoder_n_layers_hidden': 3, 'weight_decay': 0.0001, 'batch_size': 256, 'n_units_embedding': 350, 'decoder_n_units_hidden': 100, 'decoder_nonlin': 'tanh', 'decoder_dropout': 0.03137473872195671, 'encoder_n_layers_hidden': 5, 'encoder_n_units_hidden': 450, 'encoder_nonlin': 'leaky_relu', 'encoder_dropout': 0.06130705537690631}
# [2023-09-21T11:58:43.313149+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 100/100 [02:30<00:00,  1.50s/it]

# %% [markdown]
# You have an access to the best hyperparamters.

# %%
best_hyperparameters = tvae_synthetic_data_model_optimizer.best_hyperparameters
print(best_hyperparameters)
# Out:
# {'n_iter': 100, 'lr': 0.001, 'decoder_n_layers_hidden': 3, 'weight_decay': 0.0001, 'batch_size': 256, 'n_units_embedding': 350, 'decoder_n_units_hidden': 100, 'decoder_nonlin': 'tanh', 'decoder_dropout': 0.03137473872195671, 'encoder_n_layers_hidden': 5, 'encoder_n_units_hidden': 450, 'encoder_nonlin': 'leaky_relu', 'encoder_dropout': 0.06130705537690631}

# %% [markdown]
# You can also plot /display parallel hyperparamter coordinates for later analysis.

# %%
tvae_synthetic_data_model_optimizer.display_parallel_hyperparameter_coordinates()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c7ad1468-a50a-475a-b1c4-d80a8032051d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7ad1468-a50a-475a-b1c4-d80a8032051d")) {                    Plotly.newPlot(                        "c7ad1468-a50a-475a-b1c4-d80a8032051d",                        [{"dimensions":[{"label":"Objective Value","range":[0.6576714792321535,0.80011811208609],"values":[0.80011811208609,0.6576714792321535]},{"label":"batch_size","range":[0,1],"ticktext":["256","512"],"tickvals":[0,1],"values":[0,1]},{"label":"decoder_dropout","range":[0.03137473872195671,0.11346204368066007],"values":[0.03137473872195671,0.11346204368066007]},{"label":"decoder_n_layers_...","range":[1,3],"values":[3,1]},{"label":"decoder_n_units_h...","range":[100,250],"values":[100,250]},{"label":"decoder_nonlin","range":[0,1],"ticktext":["elu","tanh"],"tickvals":[0,1],"values":[1,0]},{"label":"encoder_dropout","range":[0.05081501879035502,0.06130705537690631],"values":[0.06130705537690631,0.05081501879035502]},{"label":"encoder_n_layers_...","range":[5,5],"values":[5,5]},{"label":"encoder_n_units_h...","range":[150,450],"values":[450,150]},{"label":"encoder_nonlin","range":[0,1],"ticktext":["tanh","leaky_relu"],"tickvals":[0,1],"values":[1,0]},{"label":"lr","range":[0,1],"ticktext":["0.0001","0.001"],"tickvals":[0,1],"values":[1,0]},{"label":"n_iter","range":[100,400],"values":[100,400]},{"label":"n_units_embedding","range":[250,350],"values":[350,250]},{"label":"weight_decay","range":[0,1],"ticktext":["0.0001","0.001"],"tickvals":[0,1],"values":[0,1]}],"labelangle":30,"labelside":"bottom","line":{"color":[0.80011811208609,0.6576714792321535],"colorbar":{"title":{"text":"Objective Value"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"reversescale":false,"showscale":true},"type":"parcoords"}],                        {"title":{"text":"Parallel Coordinate Plot"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{ ...

# %% [markdown]
# There is also a method to display / plot hyperparamter importances during training.

# %%
tvae_synthetic_data_model_optimizer.display_hyperparameter_importances()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="25537c02-0852-4653-bafc-c438b1e3a8ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25537c02-0852-4653-bafc-c438b1e3a8ec")) {                    Plotly.newPlot(                        "25537c02-0852-4653-bafc-c438b1e3a8ec",                        [{"cliponaxis":false,"hovertemplate":["batch_size (CategoricalDistribution): 0.0\u003cextra\u003e\u003c\u002fextra\u003e","encoder_n_layers_hidden (IntDistribution): 0.0\u003cextra\u003e\u003c\u002fextra\u003e","decoder_n_layers_hidden (IntDistribution): 0.008547008547008546\u003cextra\u003e\u003c\u002fextra\u003e","decoder_nonlin (CategoricalDistribution): 0.025641025641025675\u003cextra\u003e\u003c\u002fextra\u003e","lr (CategoricalDistribution): 0.03418803418803424\u003cextra\u003e\u003c\u002fextra\u003e","encoder_nonlin (CategoricalDistribution): 0.051282051282051364\u003cextra\u003e\u003c\u002fextra\u003e","weight_decay (CategoricalDistribution): 0.05982905982905991\u003cextra\u003e\u003c\u002fextra\u003e","decoder_n_units_hidden (IntDistribution): 0.11965811965811964\u003cextra\u003e\u003c\u002fextra\u003e","encoder_n_units_hidden (IntDistribution): 0.12820512820512822\u003cextra\u003e\u003c\u002fextra\u003e","encoder_dropout (FloatDistribution): 0.13675213675213674\u003cextra\u003e\u003c\u002fextra\u003e","n_iter (IntDistribution): 0.13675213675213674\u003cextra\u003e\u003c\u002fextra\u003e","decoder_dropout (FloatDistribution): 0.1452991452991453\u003cextra\u003e\u003c\u002fextra\u003e","n_units_embedding (IntDistribution): 0.15384615384615383\u003cextra\u003e\u003c\u002fextra\u003e"],"marker":{"color":"rgb(66,146,198)"},"orientation":"h","text":["\u003c0.01","\u003c0.01","\u003c0.01","0.03","0.03","0.05","0.06","0.12","0.13","0.14","0.14","0.15","0.15"],"textposition":"outside","x":[0.0,0.0,0.008547008547008546,0.025641025641025675,0.03418803418803424,0.051282051282051364,0.05982905982905991,0.11965811965811964,0.12820512820512822,0.13675213675213674,0.13675213675213674,0.1452991452991453,0.15384615384615383],"y":["batch_size","encoder_n_layers_hidden","decoder_n_layers_hidden","decoder_nonlin","lr","encoder_nonlin","weight_decay","decoder_n_units_hidden","encoder_n_units_hidden","encoder_dropout","n_iter","decoder_dropout","n_units_embedding"],"type":"bar"}],                        {"showlegend":false,"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Importance for Objective Value"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl" ...

# %% [markdown]
# The tuner can also provide you with an evaluation report on the idenitifed best synthetic data model. The model will be assessed using *all* the available evaluation metrics in the *synthcity* package.

# %%
best_tvae_model_full_evaluation_report = tvae_synthetic_data_model_optimizer.best_synthetic_data_model_full_evaluation_report
best_tvae_model_full_evaluation_report
# Out:
# [2023-09-21T12:01:16.459147+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]
#                                                          min        max  \
# sanity.data_mismatch.score                          0.000000   0.000000
# sanity.common_rows_proportion.score                 0.000000   0.000000
# sanity.nearest_syn_neighbor_distance.mean           0.073798   0.073798
# sanity.close_values_probability.score               0.960212   0.960212
# sanity.distant_values_probability.score             0.001326   0.001326
# stats.jensenshannon_dist.marginal                   0.025950   0.025950
# stats.chi_squared_test.marginal                     0.432897   0.432897
# stats.inv_kl_divergence.marginal                    0.800338   0.800338
# stats.ks_test.marginal                              0.822944   0.822944
# stats.max_mean_discrepancy.joint                    0.022172   0.022172
# stats.wasserstein_dist.joint                        0.121900   0.121900
# stats.prdc.precision                                0.377984   0.377984
# stats.prdc.recall                                   0.712202   0.712202
# stats.prdc.density                                  0.261804   0.261804
# stats.prdc.coverage                                 0.188329   0.188329
# stats.alpha_precision.delta_precision_alpha_OC      0.421220   0.421220
# stats.alpha_precision.delta_coverage_beta_OC        0.082670   0.082670
# stats.alpha_precision.authenticity_OC               0.828912   0.828912
# stats.alpha_precision.delta_precision_alpha_naive   0.796552   0.796552
# stats.alpha_precision.delta_coverage_beta_naive     0.206278   0.206278
# stats.alpha_precision.authenticity_naive            0.700265   0.700265
# performance.linear_model.gt                         0.360494   0.360494
# performance.linear_model.syn_id                     0.291474   0.291474
# performance.linear_model.syn_ood                    0.298303   0.298303
# performance.mlp.gt                                  0.436888   0.436888
# performance.mlp.syn_id                              0.287669   0.287669
# performance.mlp.syn_ood                             0.263516   0.263516
# performance.xgb.gt                                  0.422934   0.422934
# performance.xgb.syn_id                             -0.019229  -0.019229
# performance.xgb.syn_ood                            -0.069771  -0.069771
# performance.linear_model_augmentation.gt            0.360494   0.360494
# performance.linear_model_augmentation.aug_ood       0.298303   0.298303
# performance.mlp_augmentation.gt                     0.436888   0.436888
# performance.mlp_augmentation.aug_ood                0.263516   0.263516
# performance.xgb_augmentation.gt                     0.422934   0.422934
# performance.xgb_augmentation.aug_ood               -0.069771  -0.069771
# performance.feat_rank_distance.corr                 0.683130   0.683130
# performance.feat_rank_distance.pvalue               0.033441   0.033441
# detection.detection_xgb.mean                        0.994619   0.994619
# detection.detection_mlp.mean                        0.738913   0.738913
# detection.detection_gmm.mean                        0.467987   0.467987
# detection.detection_linear.mean                     0.797324   0.797324
# privacy.delta-presence.score                       20.000000  20.000000
# privacy.k-anonymization.gt                          2.000000   2.000000
# privacy.k-anonymization.syn                         3.000000   3.000000
# privacy.k-map.score                                 1.000000   1.000000
# privacy.distinct l-diversity.gt                     2.000000   2.000000
# privacy.distinct l-diversity.syn                    3.000000   3.000000
# privacy.identifiability_score.score                 0.058355   0.058355
# privacy.identifiability_score.score_OC              0.100796   0.100796
# privacy.DomiasMIA_BNAF.accuracy                     0.497521   0.497521
# privacy.DomiasMIA_BNAF.aucroc                       0.331701   0.331701
# privacy.DomiasMIA_KDE.accuracy                      0.498347   0.498347
# privacy.DomiasMIA_KDE.aucroc                        0.360041   0.360041
# privacy.DomiasMIA_prior.accuracy                    0.499174   0.499174
# privacy.DomiasMIA_prior.aucroc                      0.453859   0.453859
#
#                                                         mean  stddev  \
# sanity.data_mismatch.score                          0.000000     0.0
# sanity.common_rows_proportion.score                 0.000000     0.0
# sanity.nearest_syn_neighbor_distance.mean           0.073798     0.0
# sanity.close_values_probability.score               0.960212     0.0
# sanity.distant_values_probability.score             0.001326     0.0
# stats.jensenshannon_dist.marginal                   0.025950     0.0
# stats.chi_squared_test.marginal                     0.432897     0.0
# stats.inv_kl_divergence.marginal                    0.800338     0.0
# stats.ks_test.marginal                              0.822944     0.0
# stats.max_mean_discrepancy.joint                    0.022172     0.0
# stats.wasserstein_dist.joint                        0.121900     0.0
# stats.prdc.precision                                0.377984     0.0
# stats.prdc.recall                                   0.712202     0.0
# stats.prdc.density                                  0.261804     0.0
# stats.prdc.coverage                                 0.188329     0.0
# stats.alpha_precision.delta_precision_alpha_OC      0.421220     0.0
# stats.alpha_precision.delta_coverage_beta_OC        0.082670     0.0
# stats.alpha_precision.authenticity_OC               0.828912     0.0
# stats.alpha_precision.delta_precision_alpha_naive   0.796552     0.0
# stats.alpha_precision.delta_coverage_beta_naive     0.206278     0.0
# stats.alpha_precision.authenticity_naive            0.700265     0.0
# performance.linear_model.gt                         0.360494     0.0
# performance.linear_model.syn_id                     0.291474     0.0
# performance.linear_model.syn_ood                    0.298303     0.0
# performance.mlp.gt                                  0.436888     0.0
# performance.mlp.syn_id                              0.287669     0.0
# performance.mlp.syn_ood                             0.263516     0.0
# performance.xgb.gt                                  0.422934     0.0
# performance.xgb.syn_id                             -0.019229     0.0
# performance.xgb.syn_ood                            -0.069771     0.0
# performance.linear_model_augmentation.gt            0.360494     0.0
# performance.linear_model_augmentation.aug_ood       0.298303     0.0
# performance.mlp_augmentation.gt                     0.436888     0.0
# performance.mlp_augmentation.aug_ood                0.263516     0.0
# performance.xgb_augmentation.gt                     0.422934     0.0
# performance.xgb_augmentation.aug_ood               -0.069771     0.0
# performance.feat_rank_distance.corr                 0.683130     0.0
# performance.feat_rank_distance.pvalue               0.033441     0.0
# detection.detection_xgb.mean                        0.994619     0.0
# detection.detection_mlp.mean                        0.738913     0.0
# detection.detection_gmm.mean                        0.467987     0.0
# detection.detection_linear.mean                     0.797324     0.0
# privacy.delta-presence.score                       20.000000     0.0
# privacy.k-anonymization.gt                          2.000000     0.0
# privacy.k-anonymization.syn                         3.000000     0.0
# privacy.k-map.score                                 1.000000     0.0
# privacy.distinct l-diversity.gt                     2.000000     0.0
# privacy.distinct l-diversity.syn                    3.000000     0.0
# privacy.identifiability_score.score                 0.058355     0.0
# privacy.identifiability_score.score_OC              0.100796     0.0
# privacy.DomiasMIA_BNAF.accuracy                     0.497521     0.0
# privacy.DomiasMIA_BNAF.aucroc                       0.331701     0.0
# privacy.DomiasMIA_KDE.accuracy                      0.498347     0.0
# privacy.DomiasMIA_KDE.aucroc                        0.360041     0.0
# privacy.DomiasMIA_prior.accuracy                    0.499174     0.0
# privacy.DomiasMIA_prior.aucroc                      0.453859     0.0
#
#                                                       median  iqr rounds  \
# sanity.data_mismatch.score                          0.000000  0.0      1
# sanity.common_rows_proportion.score                 0.000000  0.0      1
# sanity.nearest_syn_neighbor_distance.mean           0.073798  0.0      1
# sanity.close_values_probability.score               0.960212  0.0      1
# sanity.distant_values_probability.score             0.001326  0.0      1
# stats.jensenshannon_dist.marginal                   0.025950  0.0      1
# stats.chi_squared_test.marginal                     0.432897  0.0      1
# stats.inv_kl_divergence.marginal                    0.800338  0.0      1
# stats.ks_test.marginal                              0.822944  0.0      1
# stats.max_mean_discrepancy.joint                    0.022172  0.0      1
# stats.wasserstein_dist.joint                        0.121900  0.0      1
# stats.prdc.precision                                0.377984  0.0      1
# stats.prdc.recall                                   0.712202  0.0      1
# stats.prdc.density                                  0.261804  0.0      1
# stats.prdc.coverage                                 0.188329  0.0      1
# stats.alpha_precision.delta_precision_alpha_OC      0.421220  0.0      1
# stats.alpha_precision.delta_coverage_beta_OC        0.082670  0.0      1
# stats.alpha_precision.authenticity_OC               0.828912  0.0      1
# stats.alpha_precision.delta_precision_alpha_naive   0.796552  0.0      1
# stats.alpha_precision.delta_coverage_beta_naive     0.206278  0.0      1
# stats.alpha_precision.authenticity_naive            0.700265  0.0      1
# performance.linear_model.gt                         0.360494  0.0      1
# performance.linear_model.syn_id                     0.291474  0.0      1
# performance.linear_model.syn_ood                    0.298303  0.0      1
# performance.mlp.gt                                  0.436888  0.0      1
# performance.mlp.syn_id                              0.287669  0.0      1
# performance.mlp.syn_ood                             0.263516  0.0      1
# performance.xgb.gt                                  0.422934  0.0      1
# performance.xgb.syn_id                             -0.019229  0.0      1
# performance.xgb.syn_ood                            -0.069771  0.0      1
# performance.linear_model_augmentation.gt            0.360494  0.0      1
# performance.linear_model_augmentation.aug_ood       0.298303  0.0      1
# performance.mlp_augmentation.gt                     0.436888  0.0      1
# performance.mlp_augmentation.aug_ood                0.263516  0.0      1
# performance.xgb_augmentation.gt                     0.422934  0.0      1
# performance.xgb_augmentation.aug_ood               -0.069771  0.0      1
# performance.feat_rank_distance.corr                 0.683130  0.0      1
# performance.feat_rank_distance.pvalue               0.033441  0.0      1
# detection.detection_xgb.mean                        0.994619  0.0      1
# detection.detection_mlp.mean                        0.738913  0.0      1
# detection.detection_gmm.mean                        0.467987  0.0      1
# detection.detection_linear.mean                     0.797324  0.0      1
# privacy.delta-presence.score                       20.000000  0.0      1
# privacy.k-anonymization.gt                          2.000000  0.0      1
# privacy.k-anonymization.syn                         3.000000  0.0      1
# privacy.k-map.score                                 1.000000  0.0      1
# privacy.distinct l-diversity.gt                     2.000000  0.0      1
# privacy.distinct l-diversity.syn                    3.000000  0.0      1
# privacy.identifiability_score.score                 0.058355  0.0      1
# privacy.identifiability_score.score_OC              0.100796  0.0      1
# privacy.DomiasMIA_BNAF.accuracy                     0.497521  0.0      1
# privacy.DomiasMIA_BNAF.aucroc                       0.331701  0.0      1
# privacy.DomiasMIA_KDE.accuracy                      0.498347  0.0      1
# privacy.DomiasMIA_KDE.aucroc                        0.360041  0.0      1
# privacy.DomiasMIA_prior.accuracy                    0.499174  0.0      1
# privacy.DomiasMIA_prior.aucroc                      0.453859  0.0      1
#
#                                                   errors  durations direction
# sanity.data_mismatch.score                             0       0.00  minimize
# sanity.common_rows_proportion.score                    0       0.01  minimize
# sanity.nearest_syn_neighbor_distance.mean              0       0.00  minimize
# sanity.close_values_probability.score                  0       0.00  maximize
# sanity.distant_values_probability.score                0       0.00  minimize
# stats.jensenshannon_dist.marginal                      0       0.07  minimize
# stats.chi_squared_test.marginal                        0       0.02  maximize
# stats.inv_kl_divergence.marginal                       0       0.02  maximize
# stats.ks_test.marginal                                 0       0.01  maximize
# stats.max_mean_discrepancy.joint                       0       0.07  minimize
# stats.wasserstein_dist.joint                           0       0.26  minimize
# stats.prdc.precision                                   0       0.04  maximize
# stats.prdc.recall                                      0       0.04  maximize
# stats.prdc.density                                     0       0.04  maximize
# stats.prdc.coverage                                    0       0.04  maximize
# stats.alpha_precision.delta_precision_alpha_OC         0       2.44  maximize
# stats.alpha_precision.delta_coverage_beta_OC           0       2.44  maximize
# stats.alpha_precision.authenticity_OC                  0       2.44  maximize
# stats.alpha_precision.delta_precision_alpha_naive      0       2.44  maximize
# stats.alpha_precision.delta_coverage_beta_naive        0       2.44  maximize
# stats.alpha_precision.authenticity_naive               0       2.44  maximize
# performance.linear_model.gt                            0       0.08  maximize
# performance.linear_model.syn_id                        0       0.08  maximize
# performance.linear_model.syn_ood                       0       0.08  maximize
# performance.mlp.gt                                     0      36.35  maximize
# performance.mlp.syn_id                                 0      36.35  maximize
# performance.mlp.syn_ood                                0      36.35  maximize
# performance.xgb.gt                                     0       0.63  maximize
# performance.xgb.syn_id                                 0       0.63  maximize
# performance.xgb.syn_ood                                0       0.63  maximize
# performance.linear_model_augmentation.gt               0       0.03  maximize
# performance.linear_model_augmentation.aug_ood          0       0.03  maximize
# performance.mlp_augmentation.gt                        0      36.04  maximize
# performance.mlp_augmentation.aug_ood                   0      36.04  maximize
# performance.xgb_augmentation.gt                        0       2.45  maximize
# performance.xgb_augmentation.aug_ood                   0       2.45  maximize
# performance.feat_rank_distance.corr                    0       0.58  minimize
# performance.feat_rank_distance.pvalue                  0       0.58  minimize
# detection.detection_xgb.mean                           0       0.30  minimize
# detection.detection_mlp.mean                           0       4.45  minimize
# detection.detection_gmm.mean                           0       0.26  minimize
# detection.detection_linear.mean                        0       1.76  minimize
# privacy.delta-presence.score                           0       0.22  maximize
# privacy.k-anonymization.gt                             0       0.22  maximize
# privacy.k-anonymization.syn                            0       0.22  maximize
# privacy.k-map.score                                    0       0.12  maximize
# privacy.distinct l-diversity.gt                        0       0.29  maximize
# privacy.distinct l-diversity.syn                       0       0.29  maximize
# privacy.identifiability_score.score                    0       0.03  minimize
# privacy.identifiability_score.score_OC                 0       0.03  minimize
# privacy.DomiasMIA_BNAF.accuracy                        0     390.25  minimize
# privacy.DomiasMIA_BNAF.aucroc                          0     390.25  minimize
# privacy.DomiasMIA_KDE.accuracy                         0       0.30  minimize
# privacy.DomiasMIA_KDE.aucroc                           0       0.30  minimize
# privacy.DomiasMIA_prior.accuracy                       0       0.31  minimize
# privacy.DomiasMIA_prior.aucroc                         0       0.31  minimize

# %% [markdown]
# Another method will evaluate the model using only the evaluation metrics specified at the class initializaiton.

# %%
best_tvae_model_evaluation_report = tvae_synthetic_data_model_optimizer.best_synthetic_data_model_evaluation_report
best_tvae_model_evaluation_report
# Out:
#                                             min       max      mean  stddev  \
# sanity.close_values_probability.score  0.960212  0.960212  0.960212     0.0
# stats.inv_kl_divergence.marginal       0.800338  0.800338  0.800338     0.0
# performance.xgb.gt                     0.422934  0.422934  0.422934     0.0
# performance.xgb.syn_id                -0.019229 -0.019229 -0.019229     0.0
# performance.xgb.syn_ood               -0.069771 -0.069771 -0.069771     0.0
# performance.xgb_augmentation.gt        0.422934  0.422934  0.422934     0.0
# performance.xgb_augmentation.aug_ood  -0.069771 -0.069771 -0.069771     0.0
# privacy.k-anonymization.gt             2.000000  2.000000  2.000000     0.0
# privacy.k-anonymization.syn            3.000000  3.000000  3.000000     0.0
#
#                                          median  iqr rounds errors  durations  \
# sanity.close_values_probability.score  0.960212  0.0      1      0       0.00
# stats.inv_kl_divergence.marginal       0.800338  0.0      1      0       0.02
# performance.xgb.gt                     0.422934  0.0      1      0       0.63
# performance.xgb.syn_id                -0.019229  0.0      1      0       0.63
# performance.xgb.syn_ood               -0.069771  0.0      1      0       0.63
# performance.xgb_augmentation.gt        0.422934  0.0      1      0       2.45
# performance.xgb_augmentation.aug_ood  -0.069771  0.0      1      0       2.45
# privacy.k-anonymization.gt             2.000000  0.0      1      0       0.22
# privacy.k-anonymization.syn            3.000000  0.0      1      0       0.22
#
#                                       direction
# sanity.close_values_probability.score  maximize
# stats.inv_kl_divergence.marginal       maximize
# performance.xgb.gt                     maximize
# performance.xgb.syn_id                 maximize
# performance.xgb.syn_ood                maximize
# performance.xgb_augmentation.gt        maximize
# performance.xgb_augmentation.aug_ood   maximize
# privacy.k-anonymization.gt             maximize
# privacy.k-anonymization.syn            maximize

# %% [markdown]
# The tuner will also enable you to save the best synthetic data model.

# %%
tvae_synthetic_data_model_optimizer.save_best_synthetic_data_model()

# %% [markdown]
# # Synthetic data generation

# %% [markdown]
# You can create the synthetic data with the tuner or the *generate_synthetic_data_with_synthetic_data_model* function from the *synthetic_data_model_tuning* module.

# %%
tvae_synthetic_data_model_optimizer.generate_synthetic_data_with_the_best_synthetic_data_model(
    count=10,
)
# Out:
#    productsize  purchasequantity  purchaseamount  dept  category    company  \
# 0    18.698397                 3        7.220013     9       907  101111010
# 1     1.580076                 0        0.683314    97      9753      10000
# 2    17.018214                 1        1.658242     9       907  101111010
# 3    14.124072                 3        6.233899     9       907  101111010
# 4     1.110688                 1        5.533926    97      9753      10000
# 5   128.000000                 3        3.939598    63      6315  101111010
# 6    14.438870                 2        1.451398    97      9753      10000
# 7    14.592114                 1        3.874689    97      9753      10000
# 8   127.604158                 1        4.477282    63      6315  101111010
# 9     1.453900                 1        6.080414    97      9753  101111010
#
#    brand productmeasure
# 0   9907             OZ
# 1      0             CT
# 2   9907             OZ
# 3   9907             OZ
# 4      0             CT
# 5   9907             OZ
# 6      0             CT
# 7      0             CT
# 8   9907             OZ
# 9      0             CT

# %% [markdown]
# # Comparing multiple tuned synthetic data models

# %% [markdown]
# Another likely step is to compare between 2 or more tuned synthetic data models and the *auto_synthetic_data_platform* package can help with it as well.
#
# For the demo purposes, we need to tune an alternative synthetic data model following the exact same steps as above.

# %%
_CTGAN_MODEL = "ctgan"
ctgan_synthetic_data_model = plugins.Plugins().get(_CTGAN_MODEL)
# Out:
# [2023-09-21T12:11:15.408482+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py

# %%
ctgan_synthetic_data_model_optimizer = synthetic_data_model_tuning.SyntheticDataModelTuner(
    data_loader=data_loader,
    synthetic_data_model=ctgan_synthetic_data_model,
    experiment_directory=pathlib.Path(_EXPERIMENT_DIRECTORY),
    number_of_trials=_NUMBER_OF_TRIALS,
    optimization_direction=_OPTIMIZATION_DIRECTION,
    evaluation_metrics=_EVALUATION_METRICS,
    task_type=_TASK_TYPE,
)

# %%
best_ctgan_synthetic_data_model = (
    ctgan_synthetic_data_model_optimizer.best_synthetic_data_model
    )
# Out:
# INFO:hyperparameter_optimization:Specified 'evaluation_metrics': {'sanity': ['close_values_probability'], 'stats': ['inv_kl_divergence'], 'performance': ['xgb'], 'privacy': ['k-anonymization']}. Optimization direction: 'maximize'.
# INFO:hyperparameter_optimization:Trial: trial_0. Model: ctgan. Selected hyperparameters: {'generator_n_layers_hidden': 2, 'generator_n_units_hidden': 100, 'generator_nonlin': 'elu', 'n_iter': 200, 'generator_dropout': 0.13868998986166445, 'discriminator_n_layers_hidden': 2, 'discriminator_n_units_hidden': 150, 'discriminator_nonlin': 'elu', 'discriminator_n_iter': 1, 'discriminator_dropout': 0.07788077013106619, 'lr': 0.0002, 'weight_decay': 0.001, 'batch_size': 100, 'encoder_max_clusters': 6}
# [2023-09-21T12:11:15.486900+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 200/200 [02:45<00:00,  1.21it/s]
# INFO:hyperparameter_optimization:Trial: trial_1. Model: ctgan. Selected hyperparameters: {'generator_n_layers_hidden': 4, 'generator_n_units_hidden': 50, 'generator_nonlin': 'elu', 'n_iter': 800, 'generator_dropout': 0.000563054708296562, 'discriminator_n_layers_hidden': 1, 'discriminator_n_units_hidden': 50, 'discriminator_nonlin': 'relu', 'discriminator_n_iter': 2, 'discriminator_dropout': 0.1276381205532688, 'lr': 0.0002, 'weight_decay': 0.0001, 'batch_size': 500, 'encoder_max_clusters': 2}
# [2023-09-21T12:14:09.477496+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  69%|██████▊   | 549/800 [05:26<02:29,  1.68it/s]
# INFO:hyperparameter_optimization:Model: ctgan. Best hyperparameters: {'generator_n_layers_hidden': 2, 'generator_n_units_hidden': 100, 'generator_nonlin': 'elu', 'n_iter': 200, 'generator_dropout': 0.13868998986166445, 'discriminator_n_layers_hidden': 2, 'discriminator_n_units_hidden': 150, 'discriminator_nonlin': 'elu', 'discriminator_n_iter': 1, 'discriminator_dropout': 0.07788077013106619, 'lr': 0.0002, 'weight_decay': 0.001, 'batch_size': 100, 'encoder_max_clusters': 6}
# [2023-09-21T12:19:44.047245+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 200/200 [02:55<00:00,  1.14it/s]

# %%
best_ctgan_model_evaluation_report = ctgan_synthetic_data_model_optimizer.best_synthetic_data_model_evaluation_report
# Out:
# [2023-09-21T12:22:40.676206+0000][3153][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# 100%|██████████| 200/200 [02:32<00:00,  1.31it/s]

# %% [markdown]
# Finally, the last step is to compare 2 or more created evaluation reports.

# %%
evaluation_reports_to_compare = {
    "tvae": best_tvae_model_evaluation_report,
    "ctgan": best_ctgan_model_evaluation_report,
}
synthetic_data_model_tuning.compare_synthetic_data_models_full_evaluation_reports(
    evaluation_results_mapping=evaluation_reports_to_compare
)
# Out:
# <style type="text/css">
# #T_11bbc_row0_col0, #T_11bbc_row1_col1, #T_11bbc_row2_col0, #T_11bbc_row2_col1, #T_11bbc_row3_col0, #T_11bbc_row4_col0, #T_11bbc_row5_col0, #T_11bbc_row5_col1, #T_11bbc_row6_col0, #T_11bbc_row7_col0, #T_11bbc_row7_col1, #T_11bbc_row8_col0 {
#   background-color: green;
# }
# #T_11bbc_row0_col1, #T_11bbc_row1_col0, #T_11bbc_row3_col1, #T_11bbc_row4_col1, #T_11bbc_row6_col1, #T_11bbc_row8_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_11bbc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11bbc_level0_col0" class="col_heading level0 col0" >tvae</th>
#       <th id="T_11bbc_level0_col1" class="col_heading level0 col1" >ctgan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11bbc_level0_row0" class="row_heading level0 row0" >sanity.close_values_probability.score</th>
#       <td id="T_11bbc_row0_col0" class="data row0 col0" >0.960212</td>
#       <td id="T_11bbc_row0_col1" class="data row0 col1" >0.876658</td>
#     </tr>
#     <tr>
#       <th id="T_11bbc_level0_row1" class="row_heading level0 row1" >stats.inv_kl_divergence.marginal</th>
#       <td id="T_11bbc_row1_col0" class="data row1 col0" >0.800338</td>
#       <td id="T_11bbc_row1_col1" class="data row1 col1" >0.865951</td>
#     </tr>
#     <tr>
#       <th id="T_11bbc_level0_row2" class="row_heading level0 row2" >performance.xgb.gt</th>
#       <td id="T_11bbc_row2_col0" class="data row2 col0" >0.422934</td>
#       <td id="T_11bbc_row2_col1" class="data row2 col1" >0.422934</td>
#     </tr>
#     <tr>
#       <th id="T_11bbc_level0_row3" class="row_heading level0 row3" >performance.xgb.syn_id</th>
#       <td id="T_11bbc_row3_col0" class="data row3 col0" >-0.019229</td>
#       <td id="T_11bbc_row3_col1" class="data row3 col1" >-3.882884</td>
#     </tr>
#     <tr>
#       <th id="T_11bbc_level0_row4" class="row_heading level0 row4" >performance.xgb.syn_ood</th>
#       <td id="T_11bbc_row4_col0" class="data row4 col0" >-0.069771</td>
#       <td id="T_11bbc_row4_col1" class="data row4 col1" >-4.025090</td>
#     </tr>
#     <tr>
#       <th id="T_11bbc_level0_row5" class="row_heading level0 row5" >performance.xgb_augmentation.gt</th>
#       <td id="T_11bbc_row5_col0" class="data row5 col0" >0.422934</td>
#       <td id="T_11bbc_row5_col1" class="data row5 col1" >0.422934</td>
#     </tr>
#     <tr>
#       <th id="T_11bbc_level0_row6" class="row_heading level0 row6" >performance.xgb_augmentation.aug_ood</th>
#       <td id="T_11bbc_row6_col0" class="data row6 col0" >-0.069771</td>
#       <td id="T_11bbc_row6_col1" class="data row6 col1" >-4.025090</td>
#     </tr>
#     <tr>
#       <th id="T_11bbc_level0_row7" class="row_heading level0 row7" >privacy.k-anonymization.gt</th>
#       <td id="T_11bbc_row7_col0" class="data row7 col0" >2.000000</td>
#       <td id="T_11bbc_row7_col1" class="data row7 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_11bbc_level0_row8" class="row_heading level0 row8" >privacy.k-anonymization.syn</th>
#       <td id="T_11bbc_row8_col0" class="data row8 col0" >3.000000</td>
#       <td id="T_11bbc_row8_col1" class="data row8 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # License

# %% [markdown]
# The *auto_synthetic_data_platform* package is a wrapper around the *synthcity* library. Credits to: Qian, Zhaozhi and Cebere, Bogdan-Constantin and van der Schaar, Mihaela
#
# The *auto_synthetic_data_platform* package uses the Apache License (Version 2.0, January 2004) more details in the package's LICENSE file.
